# %% [markdown]
# <a href="https://colab.research.google.com/github/LokeshPanuganti15/Python/blob/main/Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2.56789,9,87.9999,40,]
k
# Out:
# [4, 2.56789, 9, 87.9999, 40]

# %%
pd.Series(k)
# Out:
# 0     4.00000
# 1     2.56789
# 2     9.00000
# 3    87.99990
# 4    40.00000
# dtype: float64

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([30, 24, 25, 43, 31, 46, 26, 41, 21, 46, 47, 26, 39, 22, 21])

# %%
a.ndim
# Out:
# 1

# %%
s=pd.Series(a)
s
# Out:
# 0     30
# 1     24
# 2     25
# 3     43
# 4     31
# 5     46
# 6     26
# 7     41
# 8     21
# 9     46
# 10    47
# 11    26
# 12    39
# 13    22
# 14    21
# dtype: int64

# %%
s[4:10]
# Out:
# 4    31
# 5    46
# 6    26
# 7    41
# 8    21
# 9    46
# dtype: int64

# %%
np.random.seed(34)
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (6, 5)

# %%
df=pd.DataFrame(b,)
df
# Out:
#      0    1    2    3    4
# 0  133  185  168  135  169
# 1  111  178  129  118  129
# 2  189  129  120  196  162
# 3  105  120  151  119  185
# 4  121  163  172  142  184
# 5  172  177  136  102  137

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Adds','Country'])
df
# Out:
#    Roll  Name  Age  Adds  Country
# 0   133   185  168   135      169
# 1   111   178  129   118      129
# 2   189   129  120   196      162
# 3   105   120  151   119      185
# 4   121   163  172   142      184
# 5   172   177  136   102      137

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Adds','Country'],index=[373,374,375,376,393,403])
df
# Out:
#      Roll  Name  Age  Adds  Country
# 373   133   185  168   135      169
# 374   111   178  129   118      129
# 375   189   129  120   196      162
# 376   105   120  151   119      185
# 393   121   163  172   142      184
# 403   172   177  136   102      137

# %%
df
# Out:
#      Roll  Name  Age  Adds  Country
# 373   133   185  168   135      169
# 374   111   178  129   118      129
# 375   189   129  120   196      162
# 376   105   120  151   119      185
# 393   121   163  172   142      184
# 403   172   177  136   102      137

# %%
df.iloc[0,0]
# Out:
# 133

# %%
df.loc[373,['Roll','Name','Age']]
# Out:
# Roll    133
# Name    185
# Age     168
# Name: 373, dtype: int64

# %%
df.iloc[0,0:3]
# Out:
# Roll    133
# Name    185
# Age     168
# Name: 373, dtype: int64

# %%
df.iloc[0,0:3]
# Out:
# Roll    133
# Name    185
# Age     168
# Name: 373, dtype: int64

# %%
df.iloc[[0,5]]
# Out:
#      Roll  Name  Age  Adds  Country
# 373   133   185  168   135      169
# 403   172   177  136   102      137

# %%
df.iloc[[1,2,4]]
# Out:
#      Roll  Name  Age  Adds  Country
# 374   111   178  129   118      129
# 375   189   129  120   196      162
# 393   121   163  172   142      184

# %%
df.loc[[374,375,393]]
# Out:
#      Roll  Name  Age  Adds  Country
# 374   111   178  129   118      129
# 375   189   129  120   196      162
# 393   121   163  172   142      184

# %%
df['Age']
# Out:
# 373    168
# 374    129
# 375    120
# 376    151
# 393    172
# 403    136
# Name: Age, dtype: int64

# %%
df[['Age','Adds']]
# Out:
#      Age  Adds
# 373  168   135
# 374  129   118
# 375  120   196
# 376  151   119
# 393  172   142
# 403  136   102

# %%
df[['Adds','Name']]
# Out:
#      Adds  Name
# 373   135   185
# 374   118   178
# 375   196   129
# 376   119   120
# 393   142   163
# 403   102   177

# %%
df[['Age','Adds','Roll']]
# Out:
#      Age  Adds  Roll
# 373  168   135   133
# 374  129   118   111
# 375  120   196   189
# 376  151   119   105
# 393  172   142   121
# 403  136   102   172

# %%
df.loc[[373,375,393],['Age','Name','Roll']]
# Out:
#      Age  Name  Roll
# 373  168   185   133
# 375  120   129   189
# 393  172   163   121

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('exercise')
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.load_dataset('diamonds')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6, 5)
