# %% [markdown]
# <a href="https://colab.research.google.com/github/LokeshPanuganti15/Python/blob/main/Day_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("path from file")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-9fc488315a8a> in <cell line: 0>()
# ----> 1 df=pd.read_csv("path from file")
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment',y='total',data=df,color='red',estimator='std')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df['fare'],color='blue')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],palette=['red','blue'],hue=df['payment'])
plt.show()

# %%
sns.boxplot(x=df['fare'],color='red')
# Out:
# <Axes: xlabel='fare'>

# %%
iris_data=sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_data['sepal_length'],color='lightgreen')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
iris_dataset=sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_data['sepal_width'],palette=['violet','red','lightgreen'],y=iris_data['species'])
plt.show()

# %%
import matplotlib.pyplot as plt
sns.boxplot(x=iris_data['sepal_length'],color='red')
plt.show()

# %%
sns.scatterplot(x=df['fare'],y=df['total'],palette=['yellow','red'],)
# Out:
# <Axes: xlabel='fare', ylabel='total'>

# %%
sns.scatterplot(x=df['fare'],y=df['total'],palette=['yellow','red'],hue=df['payment'])
plt.show()

# %%
sns.stripplot(x=df['fare'],y=df['payment'],palette=['blue','red'],hue=df['color'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.swarmplot(x=df['fare'],y=df['payment'],palette=['blue','red'],hue=df['color'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-137e0511a9aa> in <cell line: 0>()
# ----> 1 sns.swarmplot(x=df['fare'],y=df['payment'],palette=['blue','red'],hue=df['color'])
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2248     ))
#    2249
# -> 2250     p.plot_swarms(
#    2251         dodge=dodge,
#    2252         color=color,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     586                 points.draw = draw.__get__(points)
#     587
# --> 588         _draw_figure(ax.figure)
#     589         self._configure_legend(ax, _scatter_legend_artist, plot_kws)
# ...

# %%
sns.lineplot(x=df['total'],y=df['fare'])
# Out:
# <Axes: xlabel='total', ylabel='fare'>

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','blue'])
# Out:
# <Axes: xlabel='total', ylabel='fare'>

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>
